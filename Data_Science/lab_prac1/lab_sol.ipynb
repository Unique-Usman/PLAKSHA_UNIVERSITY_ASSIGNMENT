# %%
import pandas as pd

file = pd.read_excel("IndStartUpFunding.xlsx")

# %%
file
# Out:
#       Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0         1  2020-01-09 00:00:00                        BYJU’S
# 1         2  2020-01-13 00:00:00                        Shuttl
# 2         3  2020-01-09 00:00:00                     Mamaearth
# 3         4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4         5  2020-01-02 00:00:00                        Fashor
# ...     ...                  ...                           ...
# 3039   3040  2015-01-29 00:00:00                    Printvenue
# 3040   3041  2015-01-29 00:00:00                      Graphene
# 3041   3042  2015-01-30 00:00:00                Mad Street Den
# 3042   3043  2015-01-30 00:00:00                     Simplotel
# 3043   3044  2015-01-31 00:00:00              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# ...

# %%
file.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentType',
#        'Amount in USD', 'Remarks'],
#       dtype='object')

# %%
#drop column
file.drop(columns=["SubVertical", "Remarks", "Investors Name"], inplace=True)

# %%
file
# Out:
#       Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0         1  2020-01-09 00:00:00                        BYJU’S
# 1         2  2020-01-13 00:00:00                        Shuttl
# 2         3  2020-01-09 00:00:00                     Mamaearth
# 3         4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4         5  2020-01-02 00:00:00                        Fashor
# ...     ...                  ...                           ...
# 3039   3040  2015-01-29 00:00:00                    Printvenue
# 3040   3041  2015-01-29 00:00:00                      Graphene
# 3041   3042  2015-01-30 00:00:00                Mad Street Den
# 3042   3043  2015-01-30 00:00:00                     Simplotel
# 3043   3044  2015-01-31 00:00:00              couponmachine.in
#
#         Industry Vertical City  Location        InvestmentType Amount in USD
# 0                  E-Tech      Bengaluru  Private Equity Round     200000000
# ...

# %%
file["Amount in USD"] = pd.to_numeric(file["Amount in USD"], errors="coerce")

# %%
file.dropna(inplace=True)

# %%
print(file)
# Out:
#       Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0         1  2020-01-09 00:00:00                        BYJU’S
# 1         2  2020-01-13 00:00:00                        Shuttl
# 2         3  2020-01-09 00:00:00                     Mamaearth
# 3         4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4         5  2020-01-02 00:00:00                        Fashor
# ...     ...                  ...                           ...
# 2867   2868  2015-04-29 00:00:00                       Icertis
# 2868   2869  2015-04-29 00:00:00                        Tracxn
# 2870   2871  2015-04-29 00:00:00                      Tradelab
# 2871   2872  2015-04-29 00:00:00                        PiQube
# 2872   2873  2015-04-29 00:00:00               Travel Triangle
#
#                Industry Vertical City  Location        InvestmentType  \
# 0                         E-Tech      Bengaluru  Private Equity Round
# ...

# %%
file['Date dd/mm/yyyy'] = pd.to_datetime(file["Date dd/mm/yyyy"], errors='coerce')
# Out:
# /tmp/ipykernel_45180/679124757.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   file['Date dd/mm/yyyy'] = pd.to_datetime(file["Date dd/mm/yyyy"], errors='coerce')

# %%
file.dropna(inplace=True)

# %%
file
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      2020-01-09                        BYJU’S
# 1         2      2020-01-13                        Shuttl
# 2         3      2020-01-09                     Mamaearth
# 3         4      2020-01-02  https://www.wealthbucket.in/
# 4         5      2020-01-02                        Fashor
# ...     ...             ...                           ...
# 2867   2868      2015-04-29                       Icertis
# 2868   2869      2015-04-29                        Tracxn
# 2870   2871      2015-04-29                      Tradelab
# 2871   2872      2015-04-29                        PiQube
# 2872   2873      2015-04-29               Travel Triangle
#
#                Industry Vertical City  Location        InvestmentType  \
# 0                         E-Tech      Bengaluru  Private Equity Round
# 1                 Transportation        Gurgaon              Series C
# ...
